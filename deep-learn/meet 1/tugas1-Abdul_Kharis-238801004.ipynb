# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# definisi vektornya
v = np.array([2,3])
s = np.array([0,4])
print(s)

# gabungin vektor ke satu array
vecs = np.array([v, s])

# bikin titik asal (0,0) buat masing-masing
origins = np.zeros((2,2))

# mulai plotting
plt.figure(figsize=(6,6))
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.quiver(origins[:,0], origins[:,1], vecs[:,0], vecs[:,1],
           color=['red','blue'], angles='xy', scale_units='xy', scale=1)

# set batas koordinatnya biar kelihatan jelas
plt.xlim(-2,5)
plt.ylim(-2,8)
plt.gca().set_aspect('equal')
plt.grid()
plt.title("Visualisasi Vektor v dan s")
plt.show()
# Out:
# [0 4]

# %%
# jumlahin v dan s
z = v + s
print(z)

# buat plot akhirnya
vecs = np.array([v, s, z])
origin = np.zeros((3,2))

plt.axis('equal')
plt.grid()
plt.ticklabel_format(style='sci', axis='both', scilimits=(0,0))
plt.quiver(origin[:,0], origin[:,1], vecs[:,0], vecs[:,1],
           angles='xy', scale_units='xy', scale=1,
           color=['r', 'b', 'g'])
plt.show()
# Out:
# [2 7]
